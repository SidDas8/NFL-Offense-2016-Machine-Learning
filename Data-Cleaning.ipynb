# %%
# Dependencies
import pandas as pd

# %%
# Read CSV File
NFL_df = pd.read_csv("Data/raw-nflOffensive2016.csv")
NFL_df.head()
# Out:
#                 Team   Division   W   L  T    PCT  Playoffs  Pts/G  Total Pts  \
# 0  Arizona Cardinals   NFC West   7   8  1  0.469         0   26.1        418
# 1    Atlanta Falcons  NFC South  11   5  0  0.688         1   33.8        540
# 2   Baltimore Ravens  AFC North   8   8  0  0.500         0   21.4        343
# 3      Buffalo Bills   AFC East   7   9  0  0.438         0   24.9        399
# 4  Carolina Panthers  NFC South   6  10  0  0.375         0   23.1        369
#
#    Scrm Plays  ...  Rushing Att  Rushing Yds  Rushing Yds/Att  Rushing TD  \
# 0        1086  ...          399         1732              4.3          20
# 1         995  ...          421         1928              4.6          20
# 2        1079  ...          367         1463              4.0          10
# 3        1013  ...          492         2629              5.3          29
# 4        1052  ...          453         1814              4.0          16
#
# ...

# %%
# Check variable types
NFL_df.dtypes
# Out:
# Team                               object
# Division                           object
# W                                   int64
# L                                   int64
# T                                   int64
# PCT                               float64
# Playoffs                            int64
# Pts/G                             float64
# Total Pts                           int64
# Scrm Plays                          int64
# Total Yards                         int64
# Yds/P                             float64
# 1st                                 int64
# 3rd Md                              int64
# 3rd Att                             int64
# 3rd Pct                           float64
# RZ Md                               int64
# RZ Att                              int64
# RZ Pct                            float64
# Pen                                 int64
# Pen Yds                             int64
# TOP                                object
# ...

# %%
# Drop rows with null values
NFL_df.dropna()
# Out:
#                     Team   Division   W   L  T    PCT  Playoffs  Pts/G  \
# 0      Arizona Cardinals   NFC West   7   8  1  0.469         0   26.1
# 1        Atlanta Falcons  NFC South  11   5  0  0.688         1   33.8
# 2       Baltimore Ravens  AFC North   8   8  0  0.500         0   21.4
# 3          Buffalo Bills   AFC East   7   9  0  0.438         0   24.9
# 4      Carolina Panthers  NFC South   6  10  0  0.375         0   23.1
# 5          Chicago Bears  NFC North   3  13  0  0.188         0   17.4
# 6     Cincinnati Bengals  AFC North   6   9  1  0.406         0   20.3
# 7       Cleveland Browns  AFC North   1  15  0  0.063         0   16.5
# 8         Dallas Cowboys   NFC East  13   3  0  0.813         1   26.3
# 9         Denver Broncos   AFC West   9   7  0  0.563         0   20.8
# 10         Detroit Lions  NFC North   9   7  0  0.563         0   21.6
# 11     Green Bay Packers  NFC North  10   6  0  0.625         1   27.0
# ...

# %%
# Show summarized info
NFL_df.describe()
# Out:
#                W         L          T        PCT   Playoffs      Pts/G  \
# count  32.000000  32.00000  32.000000  32.000000  32.000000  32.000000
# mean    7.937500   7.93750   0.125000   0.500250   0.250000  22.768750
# std     3.202192   3.21225   0.336011   0.200136   0.439941   4.131425
# min     1.000000   2.00000   0.000000   0.063000   0.000000  14.000000
# 25%     6.000000   5.75000   0.000000   0.398250   0.000000  20.200000
# 50%     8.000000   7.50000   0.000000   0.515500   0.000000  22.800000
# 75%    10.000000   9.25000   0.000000   0.632750   0.250000  25.625000
# max    14.000000  15.00000   1.000000   0.875000   1.000000  33.800000
#
#         Total Pts   Scrm Plays  Total Yards     Yds/P  ...  Rushing Att  \
# count   32.000000    32.000000    32.000000  32.00000  ...    32.000000
# mean   364.406250  1022.937500  5606.218750   5.48125  ...   416.187500
# std     65.993577    41.153479   521.558195   0.48356  ...    39.743888
# ...

# %%
# Show original column names
NFL_df.columns
# Out:
# Index(['Team', 'Division', 'W', 'L', 'T', 'PCT', 'Playoffs', 'Pts/G',
#        'Total Pts', 'Scrm Plays', 'Total Yards', 'Yds/P', '1st', '3rd Md',
#        '3rd Att', '3rd Pct', 'RZ Md', 'RZ Att', 'RZ Pct', 'Pen', 'Pen Yds',
#        'TOP', 'TO Diff', 'Rush Yds Allowed', 'Rush Yards Allowed Per Attempt',
#        'TFL', 'TFL Pct', 'Sacks', 'Sack Pct', 'QB Hits', 'QB Hit Pct', 'Comp',
#        'Att', 'Pct Completion', 'Passing Yds', 'Pass Yds/Att', 'Yds/Comp',
#        'Pass TD', 'Int', 'Passing 1st', 'Sack Yds', 'QB Rating', 'Rushing Att',
#        'Rushing Yds', 'Rushing Yds/Att', 'Rushing TD', 'Rushing 1st', 'Rec',
#        'Receiving Yds', 'Yds/Rec', 'Receiving TD', 'Receiving 1st'],
#       dtype='object')

# %%
# Delete unnecessary/duplicate columns
Simple_NFL_df = NFL_df.drop(['Division', 'W', 'L', 'T', 'Total Pts', 'Rush Yds Allowed', 'Rush Yards Allowed Per Attempt', 'TFL', 'TFL Pct', 'Sack Yds', 'Rec', 'Receiving Yds', 'Yds/Rec', 'Receiving TD', 'Receiving 1st'], axis = 1)

# %%
# Show updated columns
Simple_NFL_df.columns
# Out:
# Index(['Team', 'PCT', 'Playoffs', 'Pts/G', 'Scrm Plays', 'Total Yards',
#        'Yds/P', '1st', '3rd Md', '3rd Att', '3rd Pct', 'RZ Md', 'RZ Att',
#        'RZ Pct', 'Pen', 'Pen Yds', 'TOP', 'TO Diff', 'Sacks', 'Sack Pct',
#        'QB Hits', 'QB Hit Pct', 'Comp', 'Att', 'Pct Completion', 'Passing Yds',
#        'Pass Yds/Att', 'Yds/Comp', 'Pass TD', 'Int', 'Passing 1st',
#        'QB Rating', 'Rushing Att', 'Rushing Yds', 'Rushing Yds/Att',
#        'Rushing TD', 'Rushing 1st'],
#       dtype='object')

# %%
# Rename Columns

# %%
# Export updated CSV file
