# %%
from sklearn import tree
import pandas as pd
import os

# %%
dirty_df = pd.read_csv(os.path.join("Data", "clean-nflOffensive2016.csv"))
dirty_df.columns
# Out:
# Index(['Unnamed: 0', 'Team Name', 'Winning %', 'Playoffs', 'Points/Game',
#        'Total Plays', 'Total Yards', 'Yards/Play', 'Total 1st Downs',
#        '3rd Down Conversions', '3rd Down Attempts', '3rd Down Conversion %',
#        'Redzone Conversions', 'Redzone Attempts', 'Redzone Conversion %',
#        'Penalties', 'Penalty Yards', 'Turnover Difference', 'Sacks', 'Sack %',
#        'QB Hits', 'QB Hit %', 'Passing Completions', 'Passing Attempts',
#        'Completion %', 'Passing Yards', 'Passing Yards/Attempt',
#        'Passing Yards/Completion', 'Passing Touchdowns', 'Interceptions',
#        'Passing on 1st Down', 'QB Rating', 'Rushing Attempts', 'Rushing Yards',
#        'Rushing Yards/Attempt', 'Rushing Touchdowns', 'Rushing on 1st Down'],
#       dtype='object')

# %%
# Delete unnecessary columns
Clean_df = dirty_df.drop(['Unnamed: 0', 'Team Name'], axis = 1)
Clean_df.head()
# Out:
#    Winning %  Playoffs  Points/Game  Total Plays  Total Yards  Yards/Play  \
# 0      0.469         0         26.1         1086         5868         5.4
# 1      0.688         1         33.8          995         6653         6.7
# 2      0.500         0         21.4         1079         5563         5.2
# 3      0.438         0         24.9         1013         5665         5.6
# 4      0.375         0         23.1         1052         5499         5.2
#
#    Total 1st Downs  3rd Down Conversions  3rd Down Attempts  \
# 0              368                    87                214
# 1              379                    75                178
# 2              316                    86                233
# 3              328                    86                210
# 4              318                    83                223
#
#    3rd Down Conversion %  ...  Passing Yards/Completion  Passing Touchdowns  \
# 0                   40.7  ...                      10.8                  28
# 1                   42.1  ...                      12.6                  38
# 2                   36.9  ...                       9.3                  20
# 3                   41.0  ...                      10.6                  17
# 4                   37.2  ...                      12.0                  21
#
#    Interceptions  Passing on 1st Down  QB Rating  Rushing Attempts  \
# 0             17                  229      81.65               399
# 1              7                  239     114.94               421
# 2             16                  205      81.12               367
# 3              7                  155      84.86               492
# 4             19                  194      73.02               453
#
#    Rushing Yards  Rushing Yards/Attempt  Rushing Touchdowns  \
# 0           1732                    4.3                  20
# 1           1928                    4.6                  20
# 2           1463                    4.0                  10
# 3           2629                    5.3                  29
# 4           1814                    4.0                  16
#
#    Rushing on 1st Down
# 0                   97
# 1                  108
# 2                   79
# 3                  146
# 4                   99
#
# [5 rows x 35 columns]

# %%
target = Clean_df["Playoffs"]
target_names = ["negative", "positive"]

# %%
data = Clean_df.drop("Playoffs", axis=1)
feature_names = data.columns
data.head()
# Out:
#    Winning %  Points/Game  Total Plays  Total Yards  Yards/Play  \
# 0      0.469         26.1         1086         5868         5.4
# 1      0.688         33.8          995         6653         6.7
# 2      0.500         21.4         1079         5563         5.2
# 3      0.438         24.9         1013         5665         5.6
# 4      0.375         23.1         1052         5499         5.2
#
#    Total 1st Downs  3rd Down Conversions  3rd Down Attempts  \
# 0              368                    87                214
# 1              379                    75                178
# 2              316                    86                233
# 3              328                    86                210
# 4              318                    83                223
#
#    3rd Down Conversion %  Redzone Conversions  ...  Passing Yards/Completion  \
# 0                   40.7                   35  ...                      10.8
# 1                   42.1                   39  ...                      12.6
# 2                   36.9                   24  ...                       9.3
# 3                   41.0                   35  ...                      10.6
# 4                   37.2                   29  ...                      12.0
#
#    Passing Touchdowns  Interceptions  Passing on 1st Down  QB Rating  \
# 0                  28             17                  229      81.65
# 1                  38              7                  239     114.94
# 2                  20             16                  205      81.12
# 3                  17              7                  155      84.86
# 4                  21             19                  194      73.02
#
#    Rushing Attempts  Rushing Yards  Rushing Yards/Attempt  Rushing Touchdowns  \
# 0               399           1732                    4.3                  20
# 1               421           1928                    4.6                  20
# 2               367           1463                    4.0                  10
# 3               492           2629                    5.3                  29
# 4               453           1814                    4.0                  16
#
#    Rushing on 1st Down
# 0                   97
# 1                  108
# 2                   79
# 3                  146
# 4                   99
#
# [5 rows x 34 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.625

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.75

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.11614461086755874, 'Winning %'),
#  (0.054299856330879484, 'Turnover Difference'),
#  (0.05353006320091702, 'Total Yards'),
#  (0.0530675832292652, 'Redzone Conversions'),
#  (0.05027092798058316, 'Passing Touchdowns'),
#  (0.04400821279890058, 'QB Rating'),
#  (0.03962614745741967, 'Sacks'),
#  (0.03962047463049851, 'Yards/Play'),
#  (0.03440164539842403, 'Redzone Attempts'),
#  (0.03302948589819772, 'Passing Yards/Completion'),
#  (0.032915606797665455, 'Points/Game'),
#  (0.03168377512397681, 'Passing Yards'),
#  (0.0292654765208457, 'QB Hits'),
#  (0.02831967973243075, 'Passing Yards/Attempt'),
#  (0.026449908879856435, 'Interceptions'),
#  (0.02559247938710255, 'Penalties'),
#  (0.02287958035065878, '3rd Down Attempts'),
#  (0.020606594552130632, 'Rushing Yards'),
#  (0.020596581957850156, 'Rushing on 1st Down'),
#  (0.019788489078392982, 'Redzone Conversion %'),
#  (0.019010778343818206, 'Rushing Yards/Attempt'),
#  (0.018393476753465688, 'Rushing Attempts'),
#  (0.018281490968950407, 'Passing Completions'),
#  (0.018194828871897266, '3rd Down Conversions'),
#  (0.018166832075733004, 'Total 1st Downs'),
#  (0.017248088458496885, '3rd Down Conversion %'),
#  (0.01595395375518865, 'Passing on 1st Down'),
#  (0.015945336380914443, 'Completion %'),
#  (0.015100939980130602, 'Total Plays'),
#  (0.014888409041432103, 'Sack %'),
#  (0.014290205155360922, 'Penalty Yards'),
#  (0.013169743660049386, 'QB Hit %'),
#  (0.012906906826546917, 'Rushing Touchdowns'),
#  (0.012351829554461133, 'Passing Attempts')]
